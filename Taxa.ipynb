# %% [markdown]
# # Pobre

# %% [markdown]
# ## (111)

# %%
def langmuir_adsorption(T, mu, energies, N, M, k_B=8.6173303*10**(-5)):
    """
    Calcula a fração de sítios ocupados (Theta) usando o modelo de Langmuir.
    
    Parâmetros:
    T : float : temperatura em Kelvin
    mu : float : potencial químico
    energies : list : lista de energias de adsorção (epsilon_i)
    N : list : lista de números de sítios não equivalentes (N_i)
    M : float : número total de sítios
    k_B : float : constante de Boltzmann (default = 8.6173303e-5 eV/K)
    
    Retorna:
    float : fração de sítios ocupados
    """
    beta = 1 / (k_B * T)
    Theta = 0.0
    
    for i in range(len(energies)):
        # Calcular o argumento da exponencial
        exp_argument = beta * (energies[i] - mu)
        
        # Evitar overflow usando np.clip
        exp_value = np.exp(np.clip(exp_argument, -700, 700))  # Limitar o valor para evitar overflow
        
        # Calcular a fração de sítios ocupados
        Theta += N[i] * exp_value / (1 + exp_value)
    
    return Theta / M

# Parâmetros do modelo
T_values = np.linspace(273.15, 700, 5)  # Faixa de temperaturas (de 273.15K a 700K)
energies = [-0.8975330947, -1.4381137441, -1.4386182804, -1.3443175243]  # Energias de adsorção em eV
N = [4, 4, 4, 4]  # Números de sítios não equivalentes
M = sum(N)  # Número total de sítios

# Faixa de valores para o potencial químico (mu)
mu_values = np.linspace(-2, 0, 16)  # De -2 eV a 0 eV com 16 pontos

# Calcular Θ para cada temperatura e valor de mu
Theta_values = np.array([[langmuir_adsorption(T, mu, energies, N, M) for mu in mu_values] for T in T_values])

# Plotar os resultados
plt.figure(figsize=(10, 8))

# Plotar uma linha para cada temperatura
for i, T in enumerate(T_values):
    plt.plot(mu_values, Theta_values[i], label=f'T = {T:.2f} K', marker='o')

# Configurar os eixos
plt.xlabel(r'Potencial Químico ($\mu$)', fontsize=20)
plt.ylabel(r'Fração de sítios ocupados ($\Theta$)', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks([-2, 0], [r"$\mu_{pobre}$", r"$\mu_{rico}$"], fontsize=20)  # Definir rótulos de μ no eixo x
plt.title('Ambiente pobre em ouro na superfície (111)', fontsize=30)

# Exibir apenas as linhas horizontais do grid
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Adicionar a legenda
plt.legend(title="Temperatura", title_fontsize=20, fontsize=20)

# Ajustar margens para melhor visualização
plt.tight_layout()

# Salvar o gráfico em alta qualidade
plt.savefig("langmuir_adsorption_plot_111_pobre.png", dpi=300, format='png', bbox_inches='tight')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# ## (110)

# %%
import matplotlib.pyplot as plt
import numpy as np

def langmuir_adsorption(T, mu, energies, N, M, k_B=8.6173303*10**(-5)):
    """
    Calcula a fração de sítios ocupados (Theta) usando o modelo de Langmuir.
    
    Parâmetros:
    T : float : temperatura em Kelvin
    mu : float : potencial químico
    energies : list : lista de energias de adsorção (epsilon_i)
    N : list : lista de números de sítios não equivalentes (N_i)
    M : float : número total de sítios
    k_B : float : constante de Boltzmann (default = 8.6173303e-5 eV/K)
    
    Retorna:
    float : fração de sítios ocupados
    """
    beta = 1 / (k_B * T)
    Theta = 0.0
    
    for i in range(len(energies)):
        # Calcular o argumento da exponencial
        exp_argument = beta * (energies[i] - mu)
        
        # Evitar overflow usando np.clip
        exp_value = np.exp(np.clip(exp_argument, -700, 700))  # Limitar o valor para evitar overflow
        
        # Calcular a fração de sítios ocupados
        Theta += N[i] * exp_value / (1 + exp_value)
    
    return Theta / M

# Parâmetros do modelo
T_values = np.linspace(273.15, 700, 5)  # Faixa de temperaturas (de 273.15K a 700K)
energies = [-0.9961621313, -0.5333156566, -1.875878641, -1.3154609174]  # Energias de adsorção em eV
N = [4, 4, 4, 4]  # Números de sítios não equivalentes
M = sum(N)  # Número total de sítios

# Faixa de valores para o potencial químico (mu)
mu_values = np.linspace(-2, 0, 16)  # De -2 eV a 0 eV com 16 pontos

# Calcular Θ para cada temperatura e valor de mu
Theta_values = np.array([[langmuir_adsorption(T, mu, energies, N, M) for mu in mu_values] for T in T_values])

# Plotar os resultados
plt.figure(figsize=(10, 8))

# Plotar uma linha para cada temperatura
for i, T in enumerate(T_values):
    plt.plot(mu_values, Theta_values[i], label=f'T = {T:.2f} K', marker='o')

# Configurar os eixos
plt.xlabel(r'Potencial Químico ($\mu$)', fontsize=20)
plt.ylabel(r'Fração de sítios ocupados ($\Theta$)', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks([-2, 0], [r"$\mu_{pobre}$", r"$\mu_{rico}$"], fontsize=20)  # Definir rótulos de μ no eixo x
plt.title('Ambiente pobre em ouro na superfície (110)', fontsize=30)

# Exibir apenas as linhas horizontais do grid
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Adicionar a legenda
plt.legend(title="Temperatura", title_fontsize=20, fontsize=20)

# Ajustar margens para melhor visualização
plt.tight_layout()

# Salvar o gráfico em alta qualidade
plt.savefig("langmuir_adsorption_surface_110_pobre.png", dpi=300, format='png', bbox_inches='tight')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# ## (100)

# %%
import matplotlib.pyplot as plt
import numpy as np

def langmuir_adsorption(T, mu, energies, N, M, k_B=8.6173303*10**(-5)): 
    """
    Calcula a fração de sítios ocupados (Theta) usando o modelo de Langmuir.
    
    Parâmetros:
    T : float : temperatura em Kelvin
    mu : float : potencial químico
    energies : list : lista de energias de adsorção (epsilon_i)
    N : list : lista de números de sítios não equivalentes (N_i)
    M : float : número total de sítios
    k_B : float : constante de Boltzmann (default = 8.6173303e-5 eV/K)
    
    Retorna:
    float : fração de sítios ocupados
    """
    beta = 1 / (k_B * T)
    Theta = 0.0
    
    for i in range(len(energies)):
        # Calcular o argumento da exponencial
        exp_argument = beta * (energies[i] - mu)
        
        # Evitar overflow usando np.clip
        exp_value = np.exp(np.clip(exp_argument, -700, 700))  # Limitar o valor para evitar overflow
        
        # Calcular a fração de sítios ocupados
        Theta += N[i] * exp_value / (1 + exp_value)
    
    return Theta / M

# Parâmetros do modelo
T_values = np.linspace(273.15, 700, 5)  # Faixa de temperaturas (de 273.15K a 700K)
energies = [-0.8983295073, -1.8312234865, -1.3213889444]  # Energias de adsorção em eV
N = [4, 4, 8]  # Números de sítios não equivalentes
M = sum(N)  # Número total de sítios

# Faixa de valores para o potencial químico (mu)
mu_values = np.linspace(-2, 0, 16)  # De -2 eV a 0 eV com 16 pontos

# Calcular Θ para cada temperatura e valor de mu
Theta_values = np.array([[langmuir_adsorption(T, mu, energies, N, M) for mu in mu_values] for T in T_values])

# Plotar os resultados
plt.figure(figsize=(10, 8))

# Plotar uma linha para cada temperatura
for i, T in enumerate(T_values):
    plt.plot(mu_values, Theta_values[i], label=f'T = {T:.2f} K', marker='o')

# Configurar os eixos
plt.xlabel(r'Potencial Químico ($\mu$)', fontsize=20)
plt.ylabel(r'Fração de sítios ocupados ($\Theta$)', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks([-2, 0], [r"$\mu_{pobre}$", r"$\mu_{rico}$"], fontsize=20)  # Definir rótulos de μ no eixo x
plt.title('Ambiente pobre em ouro na superfície (100)', fontsize=30)

# Exibir apenas as linhas horizontais do grid
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Adicionar a legenda
plt.legend(title="Temperatura", title_fontsize=20, fontsize=20)

# Ajustar margens para melhor visualização
plt.tight_layout()

# Salvar o gráfico em alta qualidade
plt.savefig("langmuir_adsorption_surface_100_pobre.png", dpi=300, format='png', bbox_inches='tight')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# # Rico

# %% [markdown]
# ## (111)

# %%
import matplotlib.pyplot as plt
import numpy as np

def langmuir_adsorption(T, mu, energies, N, M, k_B=8.6173303*10**(-5)):
    """
    Calcula a fração de sítios ocupados (Theta) usando o modelo de Langmuir.
    
    Parâmetros:
    T : float : temperatura em Kelvin
    mu : float : potencial químico
    energies : list : lista de energias de adsorção (epsilon_i)
    N : list : lista de números de sítios não equivalentes (N_i)
    M : float : número total de sítios
    k_B : float : constante de Boltzmann (default = 8.6173303e-5 eV/K)
    
    Retorna:
    float : fração de sítios ocupados
    """
    beta = 1 / (k_B * T)
    Theta = 0.0
    
    for i in range(len(energies)):
        # Calcular o argumento da exponencial
        exp_argument = beta * (energies[i] - mu)
        
        # Evitar overflow usando np.clip
        exp_value = np.exp(np.clip(exp_argument, -700, 700))  # Limitar o valor para evitar overflow
        
        # Calcular a fração de sítios ocupados
        Theta += N[i] * exp_value / (1 + exp_value)
    
    return Theta / M

# Parâmetros do modelo
T_values = np.linspace(273.15, 700, 5)  # Faixa de temperaturas (273.15K a 700K)
energies = [2.8550524264, 2.314471777, 2.3139672408, 2.4082679968]  # Energias de adsorção em eV
N = [4, 4, 4, 4]  # Números de sítios não equivalentes
M = sum(N)  # Número total de sítios

# Faixa de valores para o potencial químico (mu)
mu_values = np.linspace(2, 3, 16)  # De 2 eV a 3 eV com 16 pontos

# Calcular Θ para cada temperatura e valor de mu
Theta_values = np.array([[langmuir_adsorption(T, mu, energies, N, M) for mu in mu_values] for T in T_values])

# Plotar os resultados
plt.figure(figsize=(10, 8))

# Plotar uma linha para cada temperatura
for i, T in enumerate(T_values):
    plt.plot(mu_values, Theta_values[i], label=f'T = {T:.2f} K', marker='o')  # Adicionar marcador

# Configurar os eixos
plt.xlabel(r'Potencial Químico ($\mu$)', fontsize=20)
plt.ylabel(r'Fração de sítios ocupados ($\Theta$)', fontsize=20) 
plt.yticks(fontsize=20)
plt.xticks([2, 3], [r"$\mu_{pobre}$", r"$\mu_{rico}$"], fontsize=20)  # Rótulos no eixo x
plt.title('Ambiente rico em ouro na superfície (111)', fontsize=30)

# Exibir apenas as linhas horizontais do grid
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Adicionar a legenda
plt.legend(title="Temperatura", title_fontsize=20, fontsize=20)

# Ajustar margens para melhor visualização
plt.tight_layout()

# Salvar o gráfico em alta qualidade
plt.savefig("langmuir_adsorption_surface_111_rico.png", dpi=300, format='png', bbox_inches='tight')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# ## (110)

# %%
import matplotlib.pyplot as plt
import numpy as np

def langmuir_adsorption(T, mu, energies, N, M, k_B=8.6173303*10**(-5)):
    """
    Calcula a fração de sítios ocupados (Theta) usando o modelo de Langmuir.
    
    Parâmetros:
    T : float : temperatura em Kelvin
    mu : float : potencial químico
    energies : list : lista de energias de adsorção (epsilon_i)
    N : list : lista de números de sítios não equivalentes (N_i)
    M : float : número total de sítios
    k_B : float : constante de Boltzmann (default = 8.6173303e-5 eV/K)
    
    Retorna:
    float : fração de sítios ocupados
    """
    beta = 1 / (k_B * T)
    Theta = 0.0
    
    for i in range(len(energies)):
        # Calcular o argumento da exponencial
        exp_argument = beta * (energies[i] - mu)
        
        # Evitar overflow usando np.clip
        exp_value = np.exp(np.clip(exp_argument, -700, 700))  # Limitar o valor para evitar overflow
        
        # Calcular a fração de sítios ocupados
        Theta += N[i] * exp_value / (1 + exp_value)
    
    return Theta / M

# Parâmetros do modelo
T_values = np.linspace(273.15, 700, 5)  # Faixa de temperaturas (273.15K a 700K)
energies = [2.7564233898, 3.2192698646, 1.8767068801, 2.4371246037]  # Energias de adsorção em eV
N = [4, 4, 4, 4]  # Números de sítios não equivalentes
M = sum(N)  # Número total de sítios

# Faixa de valores para o potencial químico (mu)
mu_values = np.linspace(1, 4, 16)  # De 1 eV a 4 eV com 16 pontos

# Calcular Θ para cada temperatura e valor de mu
Theta_values = np.array([[langmuir_adsorption(T, mu, energies, N, M) for mu in mu_values] for T in T_values])

# Plotar os resultados
plt.figure(figsize=(10, 8))

# Plotar uma linha para cada temperatura
for i, T in enumerate(T_values):
    plt.plot(mu_values, Theta_values[i], label=f'T = {T:.2f} K', marker='o')  # Adicionar marcador

# Configurar os eixos
plt.xlabel(r'Potencial Químico ($\mu$)', fontsize=20)
plt.ylabel(r'Fração de sítios ocupados ($\Theta$)', fontsize=20) 
plt.yticks(fontsize=20)
plt.xticks([1, 4], [r"$\mu_{pobre}$", r"$\mu_{rico}$"], fontsize=20)  # Rótulos no eixo x
plt.title('Ambiente rico em ouro na superfície (110)', fontsize=30)

# Exibir apenas as linhas horizontais do grid
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Adicionar a legenda
plt.legend(title="Temperatura", title_fontsize=20, fontsize=20)

# Ajustar margens para melhor visualização
plt.tight_layout()

# Salvar o gráfico em alta qualidade
plt.savefig("langmuir_adsorption_surface_110_rico.png", dpi=300, format='png', bbox_inches='tight')

# Mostrar o gráfico
plt.show()

# %% [markdown]
# ## (100)

# %%
import matplotlib.pyplot as plt
import numpy as np

def langmuir_adsorption(T, mu, energies, N, M, k_B=8.6173303*10**(-5)):
    """
    Calcula a fração de sítios ocupados (Theta) usando o modelo de Langmuir.
    
    Parâmetros:
    T : float : temperatura em Kelvin
    mu : float : potencial químico
    energies : list : lista de energias de adsorção (epsilon_i)
    N : list : lista de números de sítios não equivalentes (N_i)
    M : float : número total de sítios
    k_B : float : constante de Boltzmann (default = 8.6173303e-5 eV/K)
    
    Retorna:
    float : fração de sítios ocupados
    """
    beta = 1 / (k_B * T)
    Theta = 0.0
    
    for i in range(len(energies)):
        # Calcular o argumento da exponencial
        exp_argument = beta * (energies[i] - mu)
        
        # Evitar overflow usando np.clip
        exp_value = np.exp(np.clip(exp_argument, -700, 700))  # Limitar o valor para evitar overflow
        
        # Calcular a fração de sítios ocupados
        Theta += N[i] * exp_value / (1 + exp_value)
    
    return Theta / M

# Parâmetros do modelo
T_values = np.linspace(273.15, 700, 5)  # Faixa de temperaturas (273.15K a 700K)
energies = [2.8542560138, 1.9213620346, 2.4311965767]  # Energias de adsorção em eV
N = [4, 4, 8]  # Números de sítios não equivalentes
M = sum(N)  # Número total de sítios

# Faixa de valores para o potencial químico (mu)
mu_values = np.linspace(1, 4, 16)  # De 1 eV a 4 eV com 16 pontos

# Calcular Θ para cada temperatura e valor de mu
Theta_values = np.array([[langmuir_adsorption(T, mu, energies, N, M) for mu in mu_values] for T in T_values])

# Plotar os resultados
plt.figure(figsize=(10, 8))

# Plotar uma linha para cada temperatura
for i, T in enumerate(T_values):
    plt.plot(mu_values, Theta_values[i], label=f'T = {T:.2f} K', marker='o')  # Adicionar marcador

# Configurar os eixos
plt.xlabel(r'Potencial Químico ($\mu$)', fontsize=20)
plt.ylabel(r'Fração de sítios ocupados ($\Theta$)', fontsize=20) 
plt.yticks(fontsize=20)
plt.xticks([1, 4], [r"$\mu_{pobre}$", r"$\mu_{rico}$"], fontsize=20)  # Rótulos no eixo x
plt.title('Ambiente rico em ouro na superfície (100)', fontsize=30)

# Exibir apenas as linhas horizontais do grid
plt.grid(True, axis='y', linestyle='--', alpha=0.7)

# Adicionar a legenda
plt.legend(title="Temperatura", title_fontsize=20, fontsize=20)

# Ajustar margens para melhor visualização
plt.tight_layout()

# Salvar o gráfico em alta qualidade
plt.savefig("langmuir_adsorption_surface_100_rico.png", dpi=300, format='png', bbox_inches='tight')

# Mostrar o gráfico
plt.show()
